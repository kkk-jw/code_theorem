# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc('font', family='Malgun Gothic') #윈도우, 구글 콜랩
mpl.rcParams['axes.unicode_minus'] = False #한글 폰트 사용시 마이너스 폰트 깨짐 해결
card_file1 = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
card_file2 = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드사용금액 전년동월비.xlsx')
print("사용할 엑셀 파일을 고르세요")
print()

text = input('1) 1인당 카드 사용 금액, 2)1인당 카드사용금액 전년동월비 : ')
if text == '1':
    print('<1인당 카드 사용 금액>')
    display(card_file1)
    print()
    area1 = input('어떤 지역을 입력하시겠습니까?')
    print()
    if area1 == '서울':
        print('<서울의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file1[['사용금액(백만원)기준년월','서울']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        print()
        
        if year1 == '2018':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 서울의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','서울']]))
            
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 서울의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                gp1 = plz['서울'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 서울의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['서울'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 서울의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','서울']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 서울의 1인당 카드 사용 금액 수치 값")
                plz = df.loc['21':'32']
                plz['서울'].plot(kind = 'bar',color=('g'))
                plt.show()
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 서울의 1인당 카드 사용 금액 수치 값")
                plz = df.loc['21':'32']
                gp1 = plz['서울'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.show()
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
            plt.title("2020년 서울의 1인당 카드 사용 금액 수치 값")
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','서울']]))
            print('<2020년 서울의 1인당 카드 사용 금액 수치 값>')
            
            text = input('1) bar, 2) pie : ')
            
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                display(pd.DataFrame(month1[['사용금액(백만원)기준년월','서울']]))
                plt.title("2020년 서울의 1인당 카드 사용 금액 수치 값")
                plz = df.loc['9':'20']
                plz['서울'].plot(kind = 'bar',color=('g'))
                plt.show()
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                display(pd.DataFrame(month1[['사용금액(백만원)기준년월','서울']]))
                plt.title("2020년 서울의 1인당 카드 사용 금액 수치 값")
                plz = df.loc['9':'20']
                gp1 = plz['서울'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.show()
            
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 서울의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','서울']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 서울의 1인당 카드 사용 금액 수치 값")
                plz = df.loc[:'8']
                plz['서울'].plot(kind = 'bar',color=('g'))
                plt.show()
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 서울의 1인당 카드 사용 금액 수치 값")
                plz = df.loc['1':'8']
                gp1 = plz['서울'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.show()
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        print()
        if year2 == '2018':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 서울의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','서울']]))
            
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 서울의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['서울'].plot(kind = 'bar',color=('g'))
                plt.xticks(range(len('사용금액(백만원)기준년월')))
                plt.savefig('year2.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 서울의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['서울'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.xticks(range(len('사용금액(백만원)기준년월')))
                plt.show(gp1)
                
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 서울의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','서울']]))
            
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 서울의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['서울'].plot(kind = 'bar',color=('g'))
                plt.xticks(range(len('사용금액(백만원)기준년월')))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 서울의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['서울'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.xticks(range(len('사용금액(백만원)기준년월')))
                plt.show(gp1)
                
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 서울의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','서울']]))
        
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 서울의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['서울'].plot(kind = 'bar',color=('g'))
                plt.xticks(range(len('사용금액(백만원)기준년월')))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 서울의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['서울'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.xticks(range(len('사용금액(백만원)기준년월')))
                plt.show(gp1)
            
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 서울의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','서울']]))
            
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 서울의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['서울'].plot(kind = 'bar',color=('g'))
                plt.xticks(range(len('사용금액(백만원)기준년월')))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 서울의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['서울'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.xticks(range(len('사용금액(백만원)기준년월')))
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')        
            
    elif area1 == '부산':    
        print('<부산의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file1[['사용금액(백만원)기준년월','부산']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 부산의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','부산']]))
            
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['부산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['부산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
                
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 부산의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','부산']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['부산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['부산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 부산의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','부산']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'29']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['부산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['부산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 부산의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','부산']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['부산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['부산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 부산의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','부산']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['부산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['부산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 부산의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','부산']]))
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['부산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['부산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 부산의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','부산']]))
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['부산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['부산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 부산의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','부산']]))
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['부산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['부산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
    
    elif area1 == '대구':    
        print('<대구의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file1[['사용금액(백만원)기준년월','대구']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 대구의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','대구']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대구'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['대구'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 대구의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','대구']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대구'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['대구'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 대구의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','대구']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대구'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['대구'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 대구의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','대구']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'9']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대구'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'9']    
                gp1 = plz['대구'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 대구의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','대구']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대구'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['대구'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 대구의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','대구']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대구'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['대구'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 대구의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','대구']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대구'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['21':'32']    
                gp1 = plz['대구'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 대구의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','대구']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'9']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대구'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'9']    
                gp1 = plz['대구'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')        
    
    elif area1 == '인천':    
        print('<인천의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file1[['사용금액(백만원)기준년월','인천']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 인천의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','인천']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['인천'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['인천'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 인천의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','인천']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['인천'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['인천'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 인천의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','인천']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['인천'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['인천'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 인천의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','인천']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['인천'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['인천'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 인천의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','인천']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['인천'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['인천'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 인천의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','인천']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['인천'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['인천'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 인천의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','인천']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['인천'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['인천'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 인천의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','인천']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['인천'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['인천'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')    
    
    elif area1 == '광주':    
        print('<광주의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file1[['사용금액(백만원)기준년월','광주']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 광주의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','광주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['광주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['광주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 광주의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','광주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['광주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['광주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 광주의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','광주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['광주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['광주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 광주의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','광주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['광주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['광주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 광주의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','광주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['광주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['광주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 광주의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','광주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['광주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['33':'45']    
                gp1 = plz['광주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 광주의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','광주']])) 
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['광주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['광주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 광주의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','광주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['광주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['광주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')   
            
    elif area1 == '대전':    
        print('<대전의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file1[['사용금액(백만원)기준년월','대전']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 대전의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','대전']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대전'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['대전'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 대전의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','대전']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대전'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['대전'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 대전의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','대전']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대전'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['대전'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 대전의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','대전']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대전'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['대전'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 대전의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','대전']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대전'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['대전'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 대전의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','대전']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대전'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['대전'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 대전의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','대전']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대전'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['대전'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 대전의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','대전']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대전'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['대전'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')    
    
    elif area1 == '울산':    
        print('<울산의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file1[['사용금액(백만원)기준년월','울산']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 울산의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','울산']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['울산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['울산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 울산의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','울산']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['울산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2098년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['울산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 울산의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','울산']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['울산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['울산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 울산의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','울산']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['울산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['울산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 울산의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','울산']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['울산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['울산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 울산의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','울산']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['울산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['울산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 울산의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','울산']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['울산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['울산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 울산의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','울산']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['울산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['울산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')     
         
    elif area1 == '세종':    
        print('<세종의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file1[['사용금액(백만원)기준년월','세종']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 세종의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','세종']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['세종'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['세종'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 세종의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','세종']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['세종'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['세종'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 세종의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','세종']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['세종'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['세종'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 세종의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','세종']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['세종'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['세종'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 세종의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','세종']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['세종'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['세종'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 세종의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','세종']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['세종'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['세종'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 세종의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','세종']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['세종'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['세종'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 세종의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','세종']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['세종'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['세종'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')     
    
    elif area1 == '경기':    
        print('<경기의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file1[['사용금액(백만원)기준년월','경기']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 경기의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','경기']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경기'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['경기'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 경기의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','경기']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경기'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['경기'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 경기의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','경기']]))   
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경기'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['경기'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 경기의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','경기']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경기'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['경기'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 경기의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','경기']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경기'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['경기'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 경기의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','경기']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경기'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['경기'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 경기의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','경기']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경기'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['경기'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 경기의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','경기']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경기'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['경기'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')     
            
    elif area1 == '강원':    
        print('<강원의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file1[['사용금액(백만원)기준년월','강원']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 강원의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','강원']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['강원'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['강원'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 강원의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','강원']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['강원'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['강원'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 강원의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','강원']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['강원'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['강원'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 강원의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','강원']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['강원'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['강원'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 강원의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','강원']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['강원'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['강원'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 강원의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','강원']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['강원'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['강원'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 강원의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','강원']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['강원'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['강원'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 강원의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','강원']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['강원'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['강원'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
    
    elif area1 == '충북':    
        print('<충북의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file1[['사용금액(백만원)기준년월','충북']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 충북의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','충북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['충북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 충북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','충북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['충북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 충북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','충북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['충북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 충북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','충북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['충북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 충북의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','충북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['충북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 충북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','충북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['충북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 충북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','충북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['충북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 충북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','충북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['충북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
    
    elif area1 == '충남':    
        print('<충남의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file1[['사용금액(백만원)기준년월','충남']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 충남의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','충남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['충남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 충남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','충남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['충남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 충남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','충남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['충남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 충남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','충남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['충남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 충남의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','충남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['충남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 충남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','충남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['충남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 충남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','충남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['충남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 충남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','충남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['충남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
    
    elif area1 == '전북':    
        print('<전북의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file1[['사용금액(백만원)기준년월','전북']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 전북의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','전북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['전북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 전북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','전북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['전북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 전북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','전북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['전북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 전북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','전북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['전북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 전북의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','전북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['전북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 전북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','전북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['전북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 전북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','전북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['전북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 전북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','전북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['전북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
    
    elif area1 == '전남':    
        print('<전남의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file1[['사용금액(백만원)기준년월','전남']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 전남의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','전남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['전남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 전남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','전남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['전남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 전남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','전남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['전남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 전남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','전남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['전남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 전남의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','전남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['전남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 전남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','전남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['전남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 전남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','전남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['전남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 전남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','전남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['전남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
    
    elif area1 == '경북':    
        print('<경북의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file1[['사용금액(백만원)기준년월','경북']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 경북의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','경북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['33':'45']    
                gp1 = plz['경북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 경북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','경북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['경북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 경북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','경북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['경북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 경북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','경북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['경북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 경북의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','경북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['경북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 경북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','경북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['경북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 경북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','경북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['경북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 경북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','경북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['경북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
   
    elif area1 == '경남':    
        print('<경남의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file1[['사용금액(백만원)기준년월','경남']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 경남의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','경남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['경남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 경남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','경남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['경남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 경남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','경남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['경남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 경남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','경남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['경남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 경남의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','경남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['경남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 경남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','경남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['경남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 경남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','경남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['경남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 경남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','경남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['1':'8']    
                gp1 = plz['경남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
    
    elif area1 == '제주':    
        print('<제주의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file1[['사용금액(백만원)기준년월','제주']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 제주의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','제주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['제주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['제주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 제주의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','제주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['제주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['제주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 제주의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','제주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['제주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['제주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 제주의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['사용금액(백만원)기준년월','제주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['제주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['제주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2018')])
            print('<2018년 제주의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','제주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['제주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2018년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['제주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2019')])
            print('<2019년 제주의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','제주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['제주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2019년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['제주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2020')])
            print('<2020년 제주의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','제주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['제주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2020년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['제주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file1[card_file1['사용금액(백만원)기준년월'].str.contains('2021')])
            print('<2021년 제주의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['사용금액(백만원)기준년월','제주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['제주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = pd.read_excel('C:\\Users\\kjk53\\OneDrive\\바탕 화면\\데이터 과학 이해 팀과제\\1인당 카드 사용 금액.xlsx')
                plt.title("2021년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['제주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
    else:
        print('잘못 입력되었습니다. 프로그램을 종료합니다.')
                                 
                                 
#2번 1인당 카드사용금액 전년동월비
                    
                    
elif text == '2':
    print('<1인당 카드사용금액 전년동월비>')
    display(card_file2)
    print()
    area1 = input('어떤 지역을 입력하시겠습니까?')
    print()
    if area1 == '서울':
        print('<서울의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file2[['전년동월비(%)기준년월','서울']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        print()
        
        if year1 == '2018':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 서울의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','서울']]))
            
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 서울의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                gp1 = plz['서울'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 서울의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['서울'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file1[card_file1['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 서울의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','서울']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 서울의 1인당 카드 사용 금액 수치 값")
                plz = df.loc['21':'32']
                plz['서울'].plot(kind = 'bar',color=('g'))
                plt.show()
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 서울의 1인당 카드 사용 금액 수치 값")
                plz = df.loc['21':'32']
                gp1 = plz['서울'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.show()
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file1[card_file1['전년동월비(%)기준년월'].str.contains('2020')])
            df = card_file2
            plt.title("2020년 서울의 1인당 카드 사용 금액 수치 값")
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','서울']]))
            print('<2020년 서울의 1인당 카드 사용 금액 수치 값>')
            
            text = input('1) bar, 2) pie : ')
            
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                display(pd.DataFrame(month1[['전년동월비(%)기준년월','서울']]))
                plt.title("2020년 서울의 1인당 카드 사용 금액 수치 값")
                plz = df.loc['9':'20']
                plz['서울'].plot(kind = 'bar',color=('g'))
                plt.show()
            else :
                print('<pie graph>')
                df = card_file2
                display(pd.DataFrame(month1[['전년동월비(%)기준년월','서울']]))
                plt.title("2020년 서울의 1인당 카드 사용 금액 수치 값")
                plz = df.loc['9':'20']
                gp1 = plz['서울'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.show()
            
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file1[card_file1['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 서울의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','서울']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 서울의 1인당 카드 사용 금액 수치 값")
                plz = df.loc['1':'8']
                plz['서울'].plot(kind = 'bar',color=('g'))
                plt.show()
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 서울의 1인당 카드 사용 금액 수치 값")
                plz = df.loc['1':'8']
                gp1 = plz['서울'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.show()
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        print()
        if year2 == '2018':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 서울의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','서울']]))
            
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 서울의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['서울'].plot(kind = 'bar',color=('g'))
                plt.xticks(range(len('전년동월비(%)기준년월')))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 서울의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['서울'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.xticks(range(len('전년동월비(%)기준년월')))
                plt.show(gp1)
                
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 서울의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','서울']]))
            
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 서울의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['서울'].plot(kind = 'bar',color=('g'))
                plt.xticks(range(len('전년동월비(%)기준년월')))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 서울의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['서울'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.xticks(range(len('전년동월비(%)기준년월')))
                plt.show(gp1)
                
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file1[card_file1['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 서울의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','서울']]))
        
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 서울의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['서울'].plot(kind = 'bar',color=('g'))
                plt.xticks(range(len('전년동월비(%)기준년월')))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 서울의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['서울'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.xticks(range(len('전년동월비(%)기준년월')))
                plt.show(gp1)
            
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file1[card_file1['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 서울의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','서울']]))
            
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 서울의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['서울'].plot(kind = 'bar',color=('g'))
                plt.xticks(range(len('전년동월비(%)기준년월')))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 서울의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['서울'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.xticks(range(len('전년동월비(%)기준년월')))
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')        
            
    elif area1 == '부산':    
        print('<부산의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file2[['전년동월비(%)기준년월','부산']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 부산의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','부산']]))
            
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['부산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['부산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
                
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 부산의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','부산']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['부산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['부산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 부산의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','부산']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'29']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['부산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['부산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 부산의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','부산']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['부산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['부산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 부산의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','부산']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['부산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['부산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 부산의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','부산']]))
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['부산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['부산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 부산의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','부산']]))
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['부산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['부산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 부산의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','부산']]))
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['부산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 부산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['부산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
    
    elif area1 == '대구':    
        print('<대구의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file2[['전년동월비(%)기준년월','대구']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 대구의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','대구']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대구'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['대구'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 대구의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','대구']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대구'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['대구'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 대구의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','대구']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대구'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['대구'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 대구의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','대구']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'9']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대구'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'9']    
                gp1 = plz['대구'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 대구의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','대구']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대구'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['대구'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 대구의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','대구']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대구'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['대구'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 대구의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','대구']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대구'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['21':'32']    
                gp1 = plz['대구'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 대구의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','대구']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'9']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대구'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 대구의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'9']    
                gp1 = plz['대구'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')        
    
    elif area1 == '인천':    
        print('<인천의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file1[['전년동월비(%)기준년월','인천']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 인천의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','인천']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['인천'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['인천'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 인천의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','인천']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['인천'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['인천'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 인천의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','인천']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['인천'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['인천'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 인천의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','인천']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['인천'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['인천'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 인천의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','인천']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['인천'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['인천'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 인천의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','인천']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['인천'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['인천'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 인천의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','인천']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['인천'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['인천'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 인천의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','인천']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['인천'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 인천의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['인천'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')    
    
    elif area1 == '광주':    
        print('<광주의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file2[['전년동월비(%)기준년월','광주']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 광주의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','광주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['광주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['광주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 광주의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','광주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['광주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['광주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 광주의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','광주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['광주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['광주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
        elif year1 == '2021':
            month1 = card_file2
            print('<2021년 광주의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','광주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['광주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['광주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 광주의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','광주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['광주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['광주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 광주의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','광주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['광주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['33':'45']    
                gp1 = plz['광주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 광주의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','광주']])) 
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['광주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['광주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 광주의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','광주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['광주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 광주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['광주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')   
            
    elif area1 == '대전':    
        print('<대전의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file2[['전년동월비(%)기준년월','대전']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 대전의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','대전']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대전'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['대전'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2019':
            month1 = card_file2
            print('<2019년 대전의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','대전']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대전'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['대전'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 대전의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','대전']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대전'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['대전'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = card_file2
            print('<2021년 대전의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','대전']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대전'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['대전'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 대전의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','대전']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대전'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['대전'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 대전의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','대전']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대전'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['대전'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 대전의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','대전']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대전'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['대전'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 대전의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','대전']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['대전'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 대전의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['대전'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')    
    
    elif area1 == '울산':    
        print('<울산의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file2[['전년동월비(%)기준년월','울산']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 울산의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','울산']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['울산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['울산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 울산의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','울산']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['울산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2098년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['울산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 울산의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','울산']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['울산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['울산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 울산의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','울산']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['울산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['울산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 울산의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','울산']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['울산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['울산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 울산의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','울산']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['울산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['울산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 울산의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','울산']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['울산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['울산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 울산의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','울산']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['울산'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 울산의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['울산'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')     
         
    elif area1 == '세종':    
        print('<세종의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file2[['전년동월비(%)기준년월','세종']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 세종의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','세종']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['세종'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['세종'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2019':
            month1 = card_file2
            print('<2019년 세종의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','세종']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['세종'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['세종'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 세종의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','세종']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['세종'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['세종'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 세종의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','세종']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['세종'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['세종'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 세종의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','세종']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['세종'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['세종'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 세종의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','세종']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['세종'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['세종'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 세종의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','세종']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['세종'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['세종'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 세종의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','세종']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['세종'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 세종의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['세종'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')     
    
    elif area1 == '경기':    
        print('<경기의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file2[['전년동월비(%)기준년월','경기']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 경기의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','경기']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경기'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['경기'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 경기의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','경기']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경기'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['경기'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 경기의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','경기']]))   
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경기'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['경기'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 경기의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','경기']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경기'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['경기'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 경기의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','경기']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경기'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['경기'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 경기의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','경기']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경기'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['경기'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 경기의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','경기']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경기'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['경기'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 경기의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','경기']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경기'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 경기의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['경기'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')     
            
    elif area1 == '강원':    
        print('<강원의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file2[['전년동월비(%)기준년월','강원']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = card_file2
            print('<2018년 강원의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','강원']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['강원'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['강원'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2019':
            month1 = card_file2
            print('<2019년 강원의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','강원']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['강원'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['강원'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 강원의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','강원']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['강원'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['강원'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 강원의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','강원']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['강원'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['강원'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 강원의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','강원']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['강원'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['강원'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 강원의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','강원']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['강원'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['강원'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 강원의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','강원']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['강원'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['강원'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 강원의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','강원']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['강원'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 강원의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['강원'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
    
    elif area1 == '충북':    
        print('<충북의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file2[['전년동월비(%)기준년월','충북']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 충북의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','충북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['충북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 충북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','충북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['충북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 충북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','충북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['충북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 충북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','충북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['충북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 충북의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','충북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['충북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 충북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','충북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['충북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 충북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','충북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['충북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 충북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','충북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 충북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['충북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
    
    elif area1 == '충남':    
        print('<충남의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file1[['전년동월비(%)기준년월','충남']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 충남의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','충남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['충남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 충남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','충남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['충남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 충남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','충남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['충남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 충남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','충남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['충남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 충남의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','충남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['충남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 충남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','충남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['충남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 충남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','충남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['충남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 충남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','충남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['충남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 충남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['충남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
    
    elif area1 == '전북':    
        print('<전북의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file2[['전년동월비(%)기준년월','전북']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 전북의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','전북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['전북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 전북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','전북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['전북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 전북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','전북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['전북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 전북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','전북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['전북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 전북의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','전북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['전북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 전북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','전북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['전북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 전북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','전북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['전북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 전북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','전북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 전북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['전북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
    
    elif area1 == '전남':    
        print('<전남의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file1[['전년동월비(%)기준년월','전남']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 전남의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','전남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['전남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 전남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','전남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['전남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 전남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','전남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['전남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 전남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','전남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['전남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 전남의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','전남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['전남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 전남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','전남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['전남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 전남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','전남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['전남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 전남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','전남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['전남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 전남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['전남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
    
    elif area1 == '경북':    
        print('<경북의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file2[['전년동월비(%)기준년월','경북']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 경북의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','경북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['33':'45']    
                gp1 = plz['경북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 경북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','경북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['경북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 경북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','경북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['경북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 경북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','경북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['경북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 경북의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','경북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['경북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 경북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','경북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['경북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 경북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','경북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['경북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 경북의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','경북']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경북'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 경북의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['경북'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
   
    elif area1 == '경남':    
        print('<경남의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file1[['전년동월비(%)기준년월','경남']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 경남의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','경남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['경남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 경남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','경남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['경남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 경남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','경남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['경남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 경남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','경남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['경남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 경남의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','경남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['경남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 경남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','경남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['경남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 경남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','경남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['경남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 경남의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','경남']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['경남'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 경남의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['1':'8']    
                gp1 = plz['경남'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
    
    elif area1 == '제주':    
        print('<제주의 1인당 카드 사용 금액 수치값>')
        display(pd.DataFrame(card_file2[['전년동월비(%)기준년월','제주']]))
        year1 = input('몇년도를 입력하시겠습니까? : ')
        if year1 == '2018':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 제주의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','제주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['제주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['제주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2019':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 제주의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','제주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['제주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['제주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2020':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 제주의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','제주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['제주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['제주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year1 == '2021':
            month1 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 제주의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month1[['전년동월비(%)기준년월','제주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['제주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['제주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
        year2 = input('다른연도도 입력하시겠습니까? : ')
        if year2 == '2018':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2018')])
            print('<2018년 제주의 1인당 카드 사용 금액 수치값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','제주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2018년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['제주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2018년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2018년")
                plz = df.loc['33':'45']    
                gp1 = plz['제주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2019':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2019')])
            print('<2019년 제주의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','제주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2019년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['제주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2019년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2019년")
                plz = df.loc['21':'32']    
                gp1 = plz['제주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2020':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2020')])
            print('<2020년 제주의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','제주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2020년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['제주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2020년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2020년")
                plz = df.loc['9':'20']    
                gp1 = plz['제주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
        elif year2 == '2021':
            month2 = pd.DataFrame(card_file2[card_file2['전년동월비(%)기준년월'].str.contains('2021')])
            print('<2021년 제주의 1인당 카드 사용 금액 수치 값>')
            display(pd.DataFrame(month2[['전년동월비(%)기준년월','제주']]))
            text = input('1) bar, 2) pie : ')
            if text == 'bar':
                print('<bar graph>')
                df = card_file2
                plt.title("2021년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']
                plt.ylim()
                plt.xlim(0,11)
                gp1 = plz['제주'].plot(kind = 'bar',color=('g'))
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)
            
            else :
                print('<pie graph>')
                df = card_file2
                plt.title("2021년 제주의 1인당 카드 사용 금액 수치 값")
                plt.xlabel("2021년")
                plz = df.loc['1':'8']    
                gp1 = plz['제주'].plot(kind = 'pie', autopct="%0.1f%%")
                plt.savefig('figpath.png', dpi=400)
                plt.show(gp1)      

        else:
            print('잘못 입력되었습니다. 프로그램을 종료합니다.')
    else:
         print('잘못 입력되었습니다. 프로그램을 종료합니다.')          
else:
    print('잘못 입력되었습니다. 프로그램을 종료합니다.')
# Out:
# 사용할 엑셀 파일을 고르세요
#
# 1) 1인당 카드 사용 금액, 2)1인당 카드사용금액 전년동월비 : 1
# <1인당 카드 사용 금액>
#    사용금액(백만원)기준년월    서울    부산    대구    인천    광주    대전    울산    세종    경기    강원  \
# 0        2021-09  1.82  1.51  1.46  1.53  1.68  1.63  1.53  2.01  1.75  1.46
# 1        2021-08  1.78  1.46  1.41  1.50  1.64  1.58  1.50  2.02  1.72  1.44
# 2        2021-07  1.81  1.53  1.46  1.54  1.70  1.62  1.56  2.02  1.75  1.49
# 3        2021-06  1.76  1.49  1.42  1.49  1.66  1.57  1.51  1.96  1.69  1.43
# 4        2021-05  1.79  1.50  1.45  1.51  1.67  1.63  1.51  2.04  1.75  1.46
# 5        2021-04  1.71  1.45  1.40  1.46  1.62  1.54  1.48  1.96  1.69  1.42
# 6        2021-03  1.74  1.51  1.46  1.51  1.67  1.60  1.54  2.01  1.73  1.44
# 7        2021-02  1.50  1.31  1.26  1.30  1.44  1.41  1.33  1.76  1.51  1.25
# 8        2021-01  1.54  1.37  1.33  1.34  1.50  1.47  1.43  1.85  1.54  1.29
# 9        2020-12  1.63  1.41  1.42  1.39  1.55  1.50  1.45  1.87  1.59  1.33
# ...

# %%
import csv

f = open('C://Users//kjk53//OneDrive//바탕 화면//age.csv')
data = csv.reader(f)
result = []

# %%
import csv

f = open('C://Users//kjk53//OneDrive//바탕 화면//age.csv')
data = csv.reader(f)
result = []

import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.plot(result)
plt.show()
